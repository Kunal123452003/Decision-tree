# %%
import numpy as np
from collections import Counter

# %%
class Node:
    def __init__(self,left=None, right=None,threshold=None, feature=None, value = None):
        self.left = left
        self.right = right
        self.threshold = threshold
        self.value = value
        self.feature = feature

# %%
class Decision_Tree:
    def __init__(self,min_sample_split=2, max_depth=100, n_features = None,tech = "gini"):
        self.min_sample_split=min_sample_split
        self.max_depth = max_depth
        self.n_features = n_features
        self.root = None
        self.tech = tech
        self.criteria={"gini" : self.gini,
                      "entropy": self.entropy}

    def fit(self,X,y):
        if self.n_features is None:
            self.n_features = X.shape[1]
        self.root = self.grow_tree(X,y,0)

    def grow_tree(self,X,y,depth):
        print("----------------------------------------------------------------------------------")
        print("X.shape",X.shape)
        n_rows, n_cols = X.shape
        print("rows:",n_rows," cols:",n_cols)
        n_labels = len(np.unique(y))
        print("No of labels:",n_labels)
        
        # Stop condition
        if (depth>=self.max_depth or n_labels == 1 or n_rows<self.min_sample_split):
            val = self.most_frequent_label(y)
            print(" Node(value = val):",val)
            return Node(value = val)

        # Best Split condition
        feature_index = np.random.choice(n_cols, self.n_features, replace = False)    # To randomly select features/cols
        print("feature_index:",feature_index)
        best_threshold, best_feature = self.best_split(X,y,feature_index)
        print("best_threshold:",best_threshold," best_feature:", best_feature)
    
        #Create child node
        left_index, right_index = self.split(X[:,best_feature],best_threshold)
        print("Elements is left node",len(X[left_index,:]))
        print("Elements is right node",len(X[right_index,:]))
        print('''\n
                 //
                //
                ==============
                \\
                 \\ 
                 Enter left side''')
        
        
        left = self.grow_tree(X[left_index,:],y[left_index],depth+1)
        print('''\n
                           \\
                            \\
                ==============
                            //
                           //
                 Enter right side''')
        right = self.grow_tree(X[right_index,:],y[right_index],depth+1)
        print("Returning node")
        return Node(left,right,best_threshold,best_feature)

    def most_frequent_label(self,y):    # This will return the first most frequent lable from y
        if len(y) == 0:
           return None
        count = Counter(y)
        frequency = count.most_common(1)[0][0]
        return frequency

    def entropy(self,y):
        count = np.bincount(y)   # bincount returns the frequency of elements
        P = count/len(y)
        return (-np.sum([p*np.log(p) for p in P if p>0]))

    def gini(self,y):
        count = np.bincount(y)
        P = count/len(y)
        return 1-np.sum([p**2 for p in P])
        
    def info_gain(self,X_col,y,thr):
        parent_entropy = self.criteria[self.tech](y)
        # Create Children 
        left_index, right_index = self.split(X_col,thr)

        # Returning 0 when there is only single type of label: means entropy is 0
        if len(left_index) == 0 or len(right_index) == 0:
            return 0
        
        #Calculate the Weigthed avg of Entropy of children
        n = len(y)
        w_left, w_right = len(left_index)/n, len(right_index)/n
        if 
        entro_left,entro_right = self.criteria[self.tech](y[left_index]), self.criteria[self.tech](y[right_index])
        child_entropy = w_left*entro_left + w_right*entro_right

        # Information gain
        return parent_entropy - child_entropy
        
    def split(self,X_col,threshold):
        # np.argwhere returns the index of elements which smaller than threshold
        #print("threshold in X_col:",threshold)
        left_index = np.argwhere(X_col<=threshold).flatten()
        #print("left_index:",left_index)
        right_index = np.argwhere(X_col>threshold).flatten()
        #print("right_index",right_index)
        return left_index,right_index
        
    def best_split(self,X,y,feature_index,tech):
        print("feature_index:",feature_index)
        # Setting initial info gain as -1
        best_info_gain = -1
        
        # setting initial value as none for split_index and split_threshold
        split_index= None
        split_threshold = None     

        for index in feature_index:
            print("==========================================index:", index,"===============================================")
            X_col = X[:,index]
            print("Priniting only 10 rows of X_col ", X_col[:11,])
            thres = np.unique(X_col)
            #print("thres:",thres)
            
            for thr in thres:
                #print("thr:",thr)
                gain = self.info_gain(X_col,y,thr)
                if gain>best_info_gain:
                    best_info_gain = gain
                    split_threshold = thr
                    split_index = index

        print("Best Gain:", best_info_gain)
        return split_threshold,split_index
        
    def predict(self,X):
       return np.array([self.traverse_tree(x,self.root) for x in X]) 

    def traverse_tree(self, x, node):
       print("x",x)
       if node.value is not None:
           print("node value: ",node.value)
           return node.value

       if x[node.feature]<= node.threshold:
           print("x[",x[node.feature],"] <= ",node.threshold)
           return self.traverse_tree(x,node.left)
       else:
           print("x[",x[node.feature],"] > ",node.threshold)
           return self.traverse_tree(x,node.right)
# Out:
#   Cell In[31], line 90
#     if
#        ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
from sklearn.tree import DecisionTreeRegressor, plot_tree

# %%
from sklearn import datasets
df=datasets.load_iris()
X = df.data
y = df.target

# %%
from sklearn.model_selection import train_test_split

# %%
X_train ,X_test, y_train, y_test = train_test_split(X,y,test_size = 0.3,random_state = 42)

# %%
reg = DecisionTreeRegressor()

# %%
reg.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred = reg.predict(X_test)

# %%
import matplotlib.pyplot as plt

# %%
from sklearn import tree

# %%
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(reg, 
                   feature_names=df.feature_names,  
                   class_names=df.target_names,
                   filled=True)

# %%
print(tree.export_text(reg))
# Out:
# |--- feature_2 <= 2.45
# |   |--- value: [0.00]
# |--- feature_2 >  2.45
# |   |--- feature_2 <= 4.75
# |   |   |--- feature_3 <= 1.60
# |   |   |   |--- value: [1.00]
# |   |   |--- feature_3 >  1.60
# |   |   |   |--- value: [2.00]
# |   |--- feature_2 >  4.75
# |   |   |--- feature_3 <= 1.75
# |   |   |   |--- feature_2 <= 4.95
# |   |   |   |   |--- value: [1.00]
# |   |   |   |--- feature_2 >  4.95
# |   |   |   |   |--- feature_3 <= 1.55
# |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |--- feature_3 >  1.55
# |   |   |   |   |   |--- feature_0 <= 6.95
# |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |--- feature_0 >  6.95
# |   |   |   |   |   |   |--- value: [2.00]
# |   |   |--- feature_3 >  1.75
# |   |   |   |--- feature_2 <= 4.85
# |   |   |   |   |--- feature_1 <= 3.10
# |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |--- feature_1 >  3.10
# |   |   |   |   |   |--- value: [1.00]
# |   |   |   |--- feature_2 >  4.85
# |   |   |   |   |--- value: [2.00]

# %%
# !pip install graphviz
# Out:
# Requirement already satisfied: graphviz in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (0.20.3)

# %%
import graphviz
# DOT data
dot_data = tree.export_graphviz(reg, out_file=None, 
                                feature_names=df.feature_names,  
                                class_names=df.target_names,
                                filled=True)

# Draw graph
graph = graphviz.Source(dot_data, format="png") 
graph

# %%
D_reg = Decision_Tree()

# %%
D_reg.fit(X_train,y_train)
# Out:
# ----------------------------------------------------------------------------------
# X.shape (105, 4)
# rows: 105  cols: 4
# No of labels: 3
# feature_index: [1 0 3 2]
# feature_index: [1 0 3 2]
# ==========================================index: 1 ===============================================
# Priniting only 10 rows of X_col  [2.4 2.8 3.1 3.  3.6 2.9 3.  3.  3.5 2.8 2.7]
# ==========================================index: 0 ===============================================
# Priniting only 10 rows of X_col  [5.5 6.3 6.4 6.6 7.2 5.7 7.6 5.6 5.1 7.7 5.8]
# ==========================================index: 3 ===============================================
# Priniting only 10 rows of X_col  [1.  1.5 1.8 1.4 2.5 1.3 2.1 1.5 0.2 2.  1. ]
# ==========================================index: 2 ===============================================
# Priniting only 10 rows of X_col  [3.7 5.1 5.5 4.4 6.1 4.2 6.6 4.5 1.4 6.7 4.1]
# Best Gain: 0.3121088435374149
# best_threshold: 0.6  best_feature: 3
# Elements is left node 31
# Elements is right node 74
#
#
#                  //
#                 //
#                 ==============
#                 \
#                  \
#                  Enter left side
# ----------------------------------------------------------------------------------
# X.shape (31, 4)
# rows: 31  cols: 4
# No of labels: 1
#  Node(value = val): 0
#
#
#                            \
#                             \
#                 ==============
#                             //
#                            //
#                  Enter right side
# ----------------------------------------------------------------------------------
# X.shape (74, 4)
# rows: 74  cols: 4
# No of labels: 2
# feature_index: [1 0 3 2]
# feature_index: [1 0 3 2]
# ==========================================index: 1 ===============================================
# Priniting only 10 rows of X_col  [2.4 2.8 3.1 3.  3.6 2.9 3.  3.  2.8 2.7 2. ]
# ==========================================index: 0 ===============================================
# Priniting only 10 rows of X_col  [5.5 6.3 6.4 6.6 7.2 5.7 7.6 5.6 7.7 5.8 5. ]
# ==========================================index: 3 ===============================================
# Priniting only 10 rows of X_col  [1.  1.5 1.8 1.4 2.5 1.3 2.1 1.5 2.  1.  1. ]
# ==========================================index: 2 ===============================================
# Priniting only 10 rows of X_col  [3.7 5.1 5.5 4.4 6.1 4.2 6.6 4.5 6.7 4.1 3.5]
# Best Gain: 0.35513673318551375
# best_threshold: 1.7  best_feature: 3
# Elements is left node 41
# Elements is right node 33
#
#
#                  //
#                 //
#                 ==============
#                 \
#                  \
#                  Enter left side
# ----------------------------------------------------------------------------------
# X.shape (41, 4)
# rows: 41  cols: 4
# No of labels: 2
# feature_index: [3 0 1 2]
# feature_index: [3 0 1 2]
# ==========================================index: 3 ===============================================
# Priniting only 10 rows of X_col  [1.  1.5 1.4 1.3 1.5 1.  1.  1.3 1.2 1.3 1. ]
# ==========================================index: 0 ===============================================
# Priniting only 10 rows of X_col  [5.5 6.3 6.6 5.7 5.6 5.8 5.  5.6 5.7 6.2 6. ]
# ==========================================index: 1 ===============================================
# Priniting only 10 rows of X_col  [2.4 2.8 3.  2.9 3.  2.7 2.  2.7 3.  2.9 2.2]
# ==========================================index: 2 ===============================================
# Priniting only 10 rows of X_col  [3.7 5.1 4.4 4.2 4.5 4.1 3.5 4.2 4.2 4.3 4. ]
# Best Gain: 0.10173082915498137
# best_threshold: 4.9  best_feature: 2
# Elements is left node 35
# Elements is right node 6
#
#
#                  //
#                 //
#                 ==============
#                 \
#                  \
#                  Enter left side
# ----------------------------------------------------------------------------------
# X.shape (35, 4)
# rows: 35  cols: 4
# No of labels: 2
# feature_index: [3 1 0 2]
# feature_index: [3 1 0 2]
# ==========================================index: 3 ===============================================
# Priniting only 10 rows of X_col  [1.  1.4 1.3 1.5 1.  1.  1.3 1.2 1.3 1.  1.5]
# ==========================================index: 1 ===============================================
# Priniting only 10 rows of X_col  [2.4 3.  2.9 3.  2.7 2.  2.7 3.  2.9 2.2 3. ]
# ==========================================index: 0 ===============================================
# Priniting only 10 rows of X_col  [5.5 6.6 5.7 5.6 5.8 5.  5.6 5.7 6.2 6.  5.4]
# ==========================================index: 2 ===============================================
# Priniting only 10 rows of X_col  [3.7 4.4 4.2 4.5 4.1 3.5 4.2 4.2 4.3 4.  4.5]
# Best Gain: 0.05551020408163265
# best_threshold: 1.5  best_feature: 3
# Elements is left node 34
# Elements is right node 1
#
#
#                  //
#                 //
#                 ==============
#                 \
#                  \
#                  Enter left side
# ----------------------------------------------------------------------------------
# X.shape (34, 4)
# rows: 34  cols: 4
# No of labels: 1
#  Node(value = val): 1
#
#
#                            \
#                             \
#                 ==============
#                             //
#                            //
#                  Enter right side
# ----------------------------------------------------------------------------------
# X.shape (1, 4)
# rows: 1  cols: 4
# No of labels: 1
#  Node(value = val): 2
# Returning node
#
#
#                            \
#                             \
#                 ==============
#                             //
#                            //
#                  Enter right side
# ----------------------------------------------------------------------------------
# X.shape (6, 4)
# rows: 6  cols: 4
# No of labels: 2
# feature_index: [3 2 0 1]
# feature_index: [3 2 0 1]
# ==========================================index: 3 ===============================================
# Priniting only 10 rows of X_col  [1.5 1.7 1.6 1.4 1.5 1.6]
# ==========================================index: 2 ===============================================
# Priniting only 10 rows of X_col  [5.1 5.  5.1 5.6 5.  5.8]
# ==========================================index: 0 ===============================================
# Priniting only 10 rows of X_col  [6.3 6.7 6.  6.1 6.  7.2]
# ==========================================index: 1 ===============================================
# Priniting only 10 rows of X_col  [2.8 3.  2.7 2.6 2.2 3. ]
# Best Gain: 0.2222222222222222
# best_threshold: 1.5  best_feature: 3
# Elements is left node 3
# Elements is right node 3
#
#
#                  //
#                 //
#                 ==============
#                 \
#                  \
#                  Enter left side
# ----------------------------------------------------------------------------------
# X.shape (3, 4)
# rows: 3  cols: 4
# No of labels: 1
#  Node(value = val): 2
#
#
#                            \
#                             \
#                 ==============
#                             //
#                            //
#                  Enter right side
# ----------------------------------------------------------------------------------
# X.shape (3, 4)
# rows: 3  cols: 4
# No of labels: 2
# feature_index: [3 2 0 1]
# feature_index: [3 2 0 1]
# ==========================================index: 3 ===============================================
# Priniting only 10 rows of X_col  [1.7 1.6 1.6]
# ==========================================index: 2 ===============================================
# Priniting only 10 rows of X_col  [5.  5.1 5.8]
# ==========================================index: 0 ===============================================
# Priniting only 10 rows of X_col  [6.7 6.  7.2]
# ==========================================index: 1 ===============================================
# Priniting only 10 rows of X_col  [3.  2.7 3. ]
# Best Gain: 0.4444444444444444
# best_threshold: 5.1  best_feature: 2
# Elements is left node 2
# Elements is right node 1
#
#
#                  //
#                 //
#                 ==============
#                 \
#                  \
#                  Enter left side
# ----------------------------------------------------------------------------------
# X.shape (2, 4)
# rows: 2  cols: 4
# No of labels: 1
#  Node(value = val): 1
#
#
#                            \
#                             \
#                 ==============
#                             //
#                            //
#                  Enter right side
# ----------------------------------------------------------------------------------
# X.shape (1, 4)
# rows: 1  cols: 4
# No of labels: 1
#  Node(value = val): 2
# Returning node
# Returning node
# Returning node
#
#
#                            \
#                             \
#                 ==============
#                             //
#                            //
#                  Enter right side
# ----------------------------------------------------------------------------------
# X.shape (33, 4)
# rows: 33  cols: 4
# No of labels: 2
# feature_index: [0 2 3 1]
# feature_index: [0 2 3 1]
# ==========================================index: 0 ===============================================
# Priniting only 10 rows of X_col  [6.4 7.2 7.6 7.7 6.3 7.7 5.7 6.  5.8 6.2 6.4]
# ==========================================index: 2 ===============================================
# Priniting only 10 rows of X_col  [5.5 6.1 6.6 6.7 4.9 6.7 5.  4.8 5.1 5.4 5.3]
# ==========================================index: 3 ===============================================
# Priniting only 10 rows of X_col  [1.8 2.5 2.1 2.  1.8 2.2 2.  1.8 1.9 2.3 1.9]
# ==========================================index: 1 ===============================================
# Priniting only 10 rows of X_col  [3.1 3.6 3.  2.8 2.7 3.8 2.5 3.  2.7 3.4 2.7]
# Best Gain: 0.018365472910927313
# best_threshold: 4.8  best_feature: 2
# Elements is left node 3
# Elements is right node 30
#
#
#                  //
#                 //
#                 ==============
#                 \
#                  \
#                  Enter left side
# ----------------------------------------------------------------------------------
# X.shape (3, 4)
# rows: 3  cols: 4
# No of labels: 2
# feature_index: [2 1 3 0]
# feature_index: [2 1 3 0]
# ==========================================index: 2 ===============================================
# Priniting only 10 rows of X_col  [4.8 4.8 4.8]
# ==========================================index: 1 ===============================================
# Priniting only 10 rows of X_col  [3.  3.2 2.8]
# ==========================================index: 3 ===============================================
# Priniting only 10 rows of X_col  [1.8 1.8 1.8]
# ==========================================index: 0 ===============================================
# Priniting only 10 rows of X_col  [6.  5.9 6.2]
# Best Gain: 0.4444444444444444
# best_threshold: 3.0  best_feature: 1
# Elements is left node 2
# Elements is right node 1
#
#
#                  //
#                 //
#                 ==============
#                 \
#                  \
#                  Enter left side
# ----------------------------------------------------------------------------------
# X.shape (2, 4)
# rows: 2  cols: 4
# No of labels: 1
#  Node(value = val): 2
#
#
#                            \
#                             \
#                 ==============
#                             //
#                            //
#                  Enter right side
# ----------------------------------------------------------------------------------
# X.shape (1, 4)
# rows: 1  cols: 4
# No of labels: 1
#  Node(value = val): 1
# Returning node
#
#
#                            \
#                             \
#                 ==============
#                             //
#                            //
#                  Enter right side
# ----------------------------------------------------------------------------------
# X.shape (30, 4)
# rows: 30  cols: 4
# No of labels: 1
#  Node(value = val): 2
# Returning node
# Returning node
# Returning node

# %%
D_reg_y_pred = D_reg.predict(X_test)
# Out:
# x [6.1 2.8 4.7 1.2]
# x[ 1.2 ] >  0.6
# x [6.1 2.8 4.7 1.2]
# x[ 1.2 ] <=  1.7
# x [6.1 2.8 4.7 1.2]
# x[ 4.7 ] <=  4.9
# x [6.1 2.8 4.7 1.2]
# x[ 1.2 ] <=  1.5
# x [6.1 2.8 4.7 1.2]
# node value:  1
# x [5.7 3.8 1.7 0.3]
# x[ 0.3 ] <=  0.6
# x [5.7 3.8 1.7 0.3]
# node value:  0
# x [7.7 2.6 6.9 2.3]
# x[ 2.3 ] >  0.6
# x [7.7 2.6 6.9 2.3]
# x[ 2.3 ] >  1.7
# x [7.7 2.6 6.9 2.3]
# x[ 6.9 ] >  4.8
# x [7.7 2.6 6.9 2.3]
# node value:  2
# x [6.  2.9 4.5 1.5]
# x[ 1.5 ] >  0.6
# x [6.  2.9 4.5 1.5]
# x[ 1.5 ] <=  1.7
# x [6.  2.9 4.5 1.5]
# x[ 4.5 ] <=  4.9
# x [6.  2.9 4.5 1.5]
# x[ 1.5 ] <=  1.5
# x [6.  2.9 4.5 1.5]
# node value:  1
# x [6.8 2.8 4.8 1.4]
# x[ 1.4 ] >  0.6
# x [6.8 2.8 4.8 1.4]
# x[ 1.4 ] <=  1.7
# x [6.8 2.8 4.8 1.4]
# x[ 4.8 ] <=  4.9
# x [6.8 2.8 4.8 1.4]
# x[ 1.4 ] <=  1.5
# x [6.8 2.8 4.8 1.4]
# node value:  1
# x [5.4 3.4 1.5 0.4]
# x[ 0.4 ] <=  0.6
# x [5.4 3.4 1.5 0.4]
# node value:  0
# x [5.6 2.9 3.6 1.3]
# x[ 1.3 ] >  0.6
# x [5.6 2.9 3.6 1.3]
# x[ 1.3 ] <=  1.7
# x [5.6 2.9 3.6 1.3]
# x[ 3.6 ] <=  4.9
# x [5.6 2.9 3.6 1.3]
# x[ 1.3 ] <=  1.5
# x [5.6 2.9 3.6 1.3]
# node value:  1
# x [6.9 3.1 5.1 2.3]
# x[ 2.3 ] >  0.6
# x [6.9 3.1 5.1 2.3]
# x[ 2.3 ] >  1.7
# x [6.9 3.1 5.1 2.3]
# x[ 5.1 ] >  4.8
# x [6.9 3.1 5.1 2.3]
# node value:  2
# x [6.2 2.2 4.5 1.5]
# x[ 1.5 ] >  0.6
# x [6.2 2.2 4.5 1.5]
# x[ 1.5 ] <=  1.7
# x [6.2 2.2 4.5 1.5]
# x[ 4.5 ] <=  4.9
# x [6.2 2.2 4.5 1.5]
# x[ 1.5 ] <=  1.5
# x [6.2 2.2 4.5 1.5]
# node value:  1
# x [5.8 2.7 3.9 1.2]
# x[ 1.2 ] >  0.6
# x [5.8 2.7 3.9 1.2]
# x[ 1.2 ] <=  1.7
# x [5.8 2.7 3.9 1.2]
# x[ 3.9 ] <=  4.9
# x [5.8 2.7 3.9 1.2]
# x[ 1.2 ] <=  1.5
# x [5.8 2.7 3.9 1.2]
# node value:  1
# x [6.5 3.2 5.1 2. ]
# x[ 2.0 ] >  0.6
# x [6.5 3.2 5.1 2. ]
# x[ 2.0 ] >  1.7
# x [6.5 3.2 5.1 2. ]
# x[ 5.1 ] >  4.8
# x [6.5 3.2 5.1 2. ]
# node value:  2
# x [4.8 3.  1.4 0.1]
# x[ 0.1 ] <=  0.6
# x [4.8 3.  1.4 0.1]
# node value:  0
# x [5.5 3.5 1.3 0.2]
# x[ 0.2 ] <=  0.6
# x [5.5 3.5 1.3 0.2]
# node value:  0
# x [4.9 3.1 1.5 0.1]
# x[ 0.1 ] <=  0.6
# x [4.9 3.1 1.5 0.1]
# node value:  0
# x [5.1 3.8 1.5 0.3]
# x[ 0.3 ] <=  0.6
# x [5.1 3.8 1.5 0.3]
# node value:  0
# x [6.3 3.3 4.7 1.6]
# x[ 1.6 ] >  0.6
# x [6.3 3.3 4.7 1.6]
# x[ 1.6 ] <=  1.7
# x [6.3 3.3 4.7 1.6]
# x[ 4.7 ] <=  4.9
# x [6.3 3.3 4.7 1.6]
# x[ 1.6 ] >  1.5
# x [6.3 3.3 4.7 1.6]
# node value:  2
# x [6.5 3.  5.8 2.2]
# x[ 2.2 ] >  0.6
# x [6.5 3.  5.8 2.2]
# x[ 2.2 ] >  1.7
# x [6.5 3.  5.8 2.2]
# x[ 5.8 ] >  4.8
# x [6.5 3.  5.8 2.2]
# node value:  2
# x [5.6 2.5 3.9 1.1]
# x[ 1.1 ] >  0.6
# x [5.6 2.5 3.9 1.1]
# x[ 1.1 ] <=  1.7
# x [5.6 2.5 3.9 1.1]
# x[ 3.9 ] <=  4.9
# x [5.6 2.5 3.9 1.1]
# x[ 1.1 ] <=  1.5
# x [5.6 2.5 3.9 1.1]
# node value:  1
# x [5.7 2.8 4.5 1.3]
# x[ 1.3 ] >  0.6
# x [5.7 2.8 4.5 1.3]
# x[ 1.3 ] <=  1.7
# x [5.7 2.8 4.5 1.3]
# x[ 4.5 ] <=  4.9
# x [5.7 2.8 4.5 1.3]
# x[ 1.3 ] <=  1.5
# x [5.7 2.8 4.5 1.3]
# node value:  1
# x [6.4 2.8 5.6 2.2]
# x[ 2.2 ] >  0.6
# x [6.4 2.8 5.6 2.2]
# x[ 2.2 ] >  1.7
# x [6.4 2.8 5.6 2.2]
# x[ 5.6 ] >  4.8
# x [6.4 2.8 5.6 2.2]
# node value:  2
# x [4.7 3.2 1.6 0.2]
# x[ 0.2 ] <=  0.6
# x [4.7 3.2 1.6 0.2]
# node value:  0
# x [6.1 3.  4.9 1.8]
# x[ 1.8 ] >  0.6
# x [6.1 3.  4.9 1.8]
# x[ 1.8 ] >  1.7
# x [6.1 3.  4.9 1.8]
# x[ 4.9 ] >  4.8
# x [6.1 3.  4.9 1.8]
# node value:  2
# x [5.  3.4 1.6 0.4]
# x[ 0.4 ] <=  0.6
# x [5.  3.4 1.6 0.4]
# node value:  0
# x [6.4 2.8 5.6 2.1]
# x[ 2.1 ] >  0.6
# x [6.4 2.8 5.6 2.1]
# x[ 2.1 ] >  1.7
# x [6.4 2.8 5.6 2.1]
# x[ 5.6 ] >  4.8
# x [6.4 2.8 5.6 2.1]
# node value:  2
# x [7.9 3.8 6.4 2. ]
# x[ 2.0 ] >  0.6
# x [7.9 3.8 6.4 2. ]
# x[ 2.0 ] >  1.7
# x [7.9 3.8 6.4 2. ]
# x[ 6.4 ] >  4.8
# x [7.9 3.8 6.4 2. ]
# node value:  2
# x [6.7 3.  5.2 2.3]
# x[ 2.3 ] >  0.6
# x [6.7 3.  5.2 2.3]
# x[ 2.3 ] >  1.7
# x [6.7 3.  5.2 2.3]
# x[ 5.2 ] >  4.8
# x [6.7 3.  5.2 2.3]
# node value:  2
# x [6.7 2.5 5.8 1.8]
# x[ 1.8 ] >  0.6
# x [6.7 2.5 5.8 1.8]
# x[ 1.8 ] >  1.7
# x [6.7 2.5 5.8 1.8]
# x[ 5.8 ] >  4.8
# x [6.7 2.5 5.8 1.8]
# node value:  2
# x [6.8 3.2 5.9 2.3]
# x[ 2.3 ] >  0.6
# x [6.8 3.2 5.9 2.3]
# x[ 2.3 ] >  1.7
# x [6.8 3.2 5.9 2.3]
# x[ 5.9 ] >  4.8
# x [6.8 3.2 5.9 2.3]
# node value:  2
# x [4.8 3.  1.4 0.3]
# x[ 0.3 ] <=  0.6
# x [4.8 3.  1.4 0.3]
# node value:  0
# x [4.8 3.1 1.6 0.2]
# x[ 0.2 ] <=  0.6
# x [4.8 3.1 1.6 0.2]
# node value:  0
# x [4.6 3.6 1.  0.2]
# x[ 0.2 ] <=  0.6
# x [4.6 3.6 1.  0.2]
# node value:  0
# x [5.7 4.4 1.5 0.4]
# x[ 0.4 ] <=  0.6
# x [5.7 4.4 1.5 0.4]
# node value:  0
# x [6.7 3.1 4.4 1.4]
# x[ 1.4 ] >  0.6
# x [6.7 3.1 4.4 1.4]
# x[ 1.4 ] <=  1.7
# x [6.7 3.1 4.4 1.4]
# x[ 4.4 ] <=  4.9
# x [6.7 3.1 4.4 1.4]
# x[ 1.4 ] <=  1.5
# x [6.7 3.1 4.4 1.4]
# node value:  1
# x [4.8 3.4 1.6 0.2]
# x[ 0.2 ] <=  0.6
# x [4.8 3.4 1.6 0.2]
# node value:  0
# x [4.4 3.2 1.3 0.2]
# x[ 0.2 ] <=  0.6
# x [4.4 3.2 1.3 0.2]
# node value:  0
# x [6.3 2.5 5.  1.9]
# x[ 1.9 ] >  0.6
# x [6.3 2.5 5.  1.9]
# x[ 1.9 ] >  1.7
# x [6.3 2.5 5.  1.9]
# x[ 5.0 ] >  4.8
# x [6.3 2.5 5.  1.9]
# node value:  2
# x [6.4 3.2 4.5 1.5]
# x[ 1.5 ] >  0.6
# x [6.4 3.2 4.5 1.5]
# x[ 1.5 ] <=  1.7
# x [6.4 3.2 4.5 1.5]
# x[ 4.5 ] <=  4.9
# x [6.4 3.2 4.5 1.5]
# x[ 1.5 ] <=  1.5
# x [6.4 3.2 4.5 1.5]
# node value:  1
# x [5.2 3.5 1.5 0.2]
# x[ 0.2 ] <=  0.6
# x [5.2 3.5 1.5 0.2]
# node value:  0
# x [5.  3.6 1.4 0.2]
# x[ 0.2 ] <=  0.6
# x [5.  3.6 1.4 0.2]
# node value:  0
# x [5.2 4.1 1.5 0.1]
# x[ 0.1 ] <=  0.6
# x [5.2 4.1 1.5 0.1]
# node value:  0
# x [5.8 2.7 5.1 1.9]
# x[ 1.9 ] >  0.6
# x [5.8 2.7 5.1 1.9]
# x[ 1.9 ] >  1.7
# x [5.8 2.7 5.1 1.9]
# x[ 5.1 ] >  4.8
# x [5.8 2.7 5.1 1.9]
# node value:  2
# x [6.  3.4 4.5 1.6]
# x[ 1.6 ] >  0.6
# x [6.  3.4 4.5 1.6]
# x[ 1.6 ] <=  1.7
# x [6.  3.4 4.5 1.6]
# x[ 4.5 ] <=  4.9
# x [6.  3.4 4.5 1.6]
# x[ 1.6 ] >  1.5
# x [6.  3.4 4.5 1.6]
# node value:  2
# x [6.7 3.1 4.7 1.5]
# x[ 1.5 ] >  0.6
# x [6.7 3.1 4.7 1.5]
# x[ 1.5 ] <=  1.7
# x [6.7 3.1 4.7 1.5]
# x[ 4.7 ] <=  4.9
# x [6.7 3.1 4.7 1.5]
# x[ 1.5 ] <=  1.5
# x [6.7 3.1 4.7 1.5]
# node value:  1
# x [5.4 3.9 1.3 0.4]
# x[ 0.4 ] <=  0.6
# x [5.4 3.9 1.3 0.4]
# node value:  0
# x [5.4 3.7 1.5 0.2]
# x[ 0.2 ] <=  0.6
# x [5.4 3.7 1.5 0.2]
# node value:  0

# %%
print(np.sum(y_pred==D_reg_y_pred)/len(X_test))
# Out:
# 0.9555555555555556

# %%
y_pred
# Out:
# array([1., 0., 2., 1., 1., 0., 1., 2., 1., 1., 2., 0., 0., 0., 0., 1., 2.,
#        1., 1., 2., 0., 2., 0., 2., 2., 2., 2., 2., 0., 0., 0., 0., 1., 0.,
#        0., 2., 1., 0., 0., 0., 2., 1., 1., 0., 0.])

# %%
D_reg_y_pred
# Out:
# array([1, 0, 2, 1, 1, 0, 1, 2, 1, 1, 2, 0, 0, 0, 0, 2, 2, 1, 1, 2, 0, 2,
#        0, 2, 2, 2, 2, 2, 0, 0, 0, 0, 1, 0, 0, 2, 1, 0, 0, 0, 2, 2, 1, 0,
#        0])
